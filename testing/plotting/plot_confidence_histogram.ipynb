# %%
# %load_ext autoreload
# %autoreload 2

import remeta
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ds = remeta.load_dataset('default')
# Out:
# ----------------------------------
# ..Generative model:
#     Type 1 noise distribution: normal
#     Type 2 noise type: report
#     Type 2 noise distribution: truncated_normal_mode
# ..Generative parameters:
#     type1_noise: 0.5
#     type1_bias: -0.1
#     type2_noise: 0.3
#     type2_criteria: [0.25 0.5  0.75]
#         [extra] Criterion bias: 0.0000
#         [extra] Criterion-based confidence bias: 0.0000
# ..Descriptive statistics:
#     No. subjects: 1
#     No. samples: 2000
#     Accuracy: 85.2% correct
#     d': 2.1
#     Choice bias: -3.9%
#     Confidence: 0.60
#     M-Ratio: 0.64
#     AUROC2: 0.69
# ----------------------------------

# %%
remeta.plot_confidence_histogram(type1_noise=1.2, type2_noise=0.9)

# %%
remeta.plot_confidence_histogram(ds, separate_by_accuracy=True, model_only=True)
# Out:
# 5000 10000

# %%
remeta.plot_confidence_histogram(ds, separate_by_accuracy=True, model_prediction=True)
# Out:
# 2000 4000

# %%
remeta.plot_confidence_histogram(ds, separate_by_category=False)

# %%
remeta.plot_confidence_histogram(ds, model_only=True, separate_by_category=True)

# %%
remeta.plot_confidence_histogram(ds, separate_by_category=False, model_prediction=True)

# %%
remeta.plot_confidence_histogram(ds, model_prediction=True)

# %%
remeta.plot_confidence_histogram(ds, separate_by_accuracy=True, model_prediction=True)
# Out:
# 2000 4000

# %%
remeta.plot_confidence_histogram(ds, separate_by_accuracy=True, model_only=True)
# Out:
# 5000 10000

# %%
remeta.plot_confidence_histogram(ds, separate_by_category=True, model_prediction=True)
